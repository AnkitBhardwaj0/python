# %%
#fake news 
import random
subject=["sachin tendulkar","virat kohli","ms dhoni","rohit sharma","cristiano ronaldo","lionel messi","neymar jr","vishwanathan anand","lebron james","serena williams","r praggnanandhaa","sunil chhetri","prime minister","president","ceo of a major company","a famous actor","a popular singer","a renowned scientist","a well-known author","a social media influencer","a top athlete"]
action=["scored a century","won the world cup","broke the record","got married","announced retirement","launched a new product","won an award","got into controversy","made a shocking statement","was involved in a scandal","was caught cheating","was arrested for fraud","was seen partying with celebrities","was spotted with a mystery person","was rumored to be dating someone famous","was seen vacationing in an exotic location","was involved in a car accident","was caught on camera doing something embarrassing","was seen at a secret location with a famous person","was involved in a heated argument with another celebrity","was seen wearing an outrageous outfit at an event"]
object=["a cricket match","a football match","a tennis match","a chess tournament","a boxing match","a basketball game","a movie premiere","a music concert","a fashion show","a political rally","a charity event","a business conference","a social gathering","a vacation spot","a restaurant","a nightclub","a shopping mall","an airport","a hotel lobby","a gymnasium"]   
while True:
    fake_news=random.choice(subject)+" "+random.choice(action)+" at "+random.choice(object)
    print(fake_news)
    user_input=input("do you want to generate another fake news ?(yes/no)")
    if user_input.lower()!="yes":
        break
# Out:
# sachin tendulkar got married at a business conference
# a famous actor was seen at a secret location with a famous person at a political rally
